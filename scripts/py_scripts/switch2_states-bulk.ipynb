# %%
# %matplotlib inline

import itertools as itt
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt
from md_distance import md_distance
from refframes import refframe_switch1
from refframes import refframe_switch2
from switch2_states_bulk import main as switch2_states

# %%
# %%time
source = 'carbon'
run = 'run3'
switch2_states(source, run, chunk_size = 100)
# Out:
# CPU times: user 41.2 s, sys: 160 ms, total: 41.4 s
# Wall time: 41.3 s

# %%
# %%time
source = 'carbon'
run = 'run3'
switch2_states(source, run, chunk_size = 1000)
# Out:
# CPU times: user 20.5 s, sys: 793 ms, total: 21.3 s
# Wall time: 21.3 s

# %%
# %%time
source = 'carbon'
run = 'run3'
switch2_states(source, run, chunk_size = 2000)
# Out:
# CPU times: user 19.7 s, sys: 716 ms, total: 20.4 s
# Wall time: 20.4 s

# %%
# %%time
source = 'carbon'
run = 'run3'
switch2_states(source, run, chunk_size = 4000)
# Out:
# CPU times: user 18.9 s, sys: 752 ms, total: 19.7 s
# Wall time: 19.7 s

# %%
# %%time
source = 'carbon'
run = 'run3'
switch2_states(source, run, chunk_size = 5001)
# Out:
# CPU times: user 19 s, sys: 687 ms, total: 19.7 s
# Wall time: 20.4 s
